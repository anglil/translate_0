# %%
# %matplotlib inline

import numpy as np
#import html # python 3.4
import os.path
import string
import sys
from random import randint

sys.path.insert(0, '/home/ec2-user/kklab/Projects/lrlp/scripts/oov_translate')
from config import *
from utils import *

# %%
tmp_dir = exp_dir+"oov_trans_bound/"
if not os.path.exists(tmp_dir):
    os.makedirs(tmp_dir)

# %%
def get_best_hyp(hyp_list, ref_sent, metric):
    '''
    pick the best hyp out of a bunch of hyp based on sentence level bleu score or meteor
    params:
        all_hyp: list of hypotheses
        ref_sent: reference sentence
        metric: bleu or meteor
    return:
        best_hyp: hypothesis with highest bleu
    '''
    hyp_file = tmp_dir+"hyp_tmp"
    ref_file_dup = tmp_dir+"ref_tmp"
    with open(hyp_file, 'w') as fw_hyp, open(ref_file_dup, 'w') as fw_ref:
        for hyp in hyp_list:
            fw_hyp.write(hyp+'\n')
            fw_ref.write(ref_sent+'\n')
    if metric == "bleu":
        stdout, stderr = sh(sent_bleu+" "+ref_file_dup+" < "+hyp_file)
        scores = stdout.strip().split('\n')
        scores = [float(item) for item in scores]
    elif metric == "meteor":
        stdout, stderr = sh("java -Xmx2G -jar "+meteor_bin+" "+hyp_file+" "+ref_file_dup+" -norm -noPunct | grep 'Segment'")
        scores = stdout.strip().split('\n')
        scores = [float(line.split('\t')[1]) for line in scores]
    else:
        raise Exception("metric \""+metric+"\" isn't supported!")
    best_idx = scores.index(max(scores))
    best_hyp = hyp_list[best_idx]
    return best_hyp
    
# def get_best_hyp_bleu(all_hyp, ref_sent, hyp_file, ref_file_dup):
#     '''
#     pick the best hyp out of a bunch of hyp based on sentence level bleu score
#     params:
#         all_hyp: list of hypotheses
#         ref_sent: reference sentence
#         hyp_file: file to write the list of hypotheses to
#         ref_file_dup: file to write the duplicated reference to
#     return:
#         best_hyp: hypothesis with highest bleu
#     '''
#     with open(hyp_file, 'w') as fw_hyp, open(ref_file_dup, 'w') as fw_ref:
#         for hyp in all_hyp:
#             fw_hyp.write(hyp+'\n')
#             fw_ref.write(ref_sent+'\n')
#     stdout, stderr = sh(sent_bleu+" "+ref_file_dup+" < "+hyp_file)
#     bleu_scores = stdout.strip().split('\n')
#     bleu_scores = [float(item) for item in bleu_scores]
#     best_bleu_idx = bleu_scores.index(max(bleu_scores))
#     best_hyp = all_hyp[best_bleu_idx]
#     return best_hyp



# def get_best_hyp_meteor(all_hyp, ref_sent, hyp_file, ref_file_dup):
#     '''
#     pick the best hyp out of a bunch of hyp based on meteor score (alignment based)
#     params:
#         all_hyp: list of hypotheses
#         ref_sent: reference sentence
#         hyp_file: file to write the list of hypotheses to
#         ref_file_dup: file to write the duplicated reference to
#     return: 
#         best_hyp: hypothesis with highest meteor
#     '''
#     with open(hyp_file, 'w') as fw_hyp, open(ref_file_dup, 'w') as fw_ref:
#         for hyp in all_hyp:
#             fw_hyp.write(hyp+'\n')
#             fw_ref.write(ref_sent+'\n')
#     stdout, stderr = sh("java -Xmx2G -jar "+meteor_bin+" "+hyp_file+" "+ref_file_dup+" -norm -noPunct | grep 'Segment'")
#     meteor_scores = stdout.strip().split('\n')
#     meteor_scores = [float(line.split('\t')[1]) for line in meteor_scores]
#     best_meteor_idx = meteor_scores.index(max(meteor_scores))
#     best_hyp = all_hyp[best_meteor_idx]
#     return best_hyp



def get_best_hyp_est(tra_tok, oov_candidates, ref_sent, metric):
    ''' 
    for sentences with lots of oovs, we translate oovs one by one, only for ug_dict
    params:
        tra_tok: tokenized translation
        oov_candidates: in ug_dict format
        ref_sent: reference sentence
        metric: "bleu" or "meteor"
    return:
        hypothesis with highest metric
    '''
    ### ./sentence-bleu ref < hyp (result is from 0 to 1)
    tra_tok_new = list(tra_tok)
    for i in range(len(tra_tok)):
        if tra_tok[i] in oov_candidates and tra_tok[i] not in oov_candidates[tra_tok[i]]:
            candidates = list(oov_candidates[tra_tok[i]].keys())
#             hyp_file = tmp_dir+"hyp_long"
#             ref_file_dup = tmp_dir+"ref_long"
            hyp_list = []
            for candidate in candidates:
                sent = list(tra_tok_new)
                sent[i] = candidate
                hyp_list.append(' '.join(sent))
#             if metric == "bleu":
#                 best_candidate = get_best_hyp_bleu(all_hyp, ref_sent, hyp_file, ref_file_dup)
#             elif metric == "meteor":
#                 best_candidate = get_best_hyp_meteor(all_hyp, ref_sent, hyp_file, ref_file_dup)
            best_candidate = get_best_hyp(hyp_list, ref_sent, metric)
            tra_tok_new[i] = candidates[hyp_list.index(best_candidate)]

    return ' '.join(tra_tok_new)



def translate_oov_by_alignment(tra_tok, oov_pos, ref_tok, pairs):
    '''
    given alignment with the reference output by fast-align, 
    output the translation without oov, 
    and mapping from oov words to words in reference
    params:
        tra_tok: tokenized translation
        oov_pos: list of positions of oov words in target lang
        ref_tok: tokenized reference
        pairs: positions pairs representing alignment between src & tgt
    return:
        res: list of translated tokens by the alignment
        oov_trans: the translation for the oov words: {oov word: set({translations})}
    '''
    ### positions in translation
    tra_lang = []
    ### positions in reference
    ref_lang = []
    for pair in pairs:
        lr = pair.split('-')
        tra_lang.append(int(lr[0]))
        ref_lang.append(int(lr[1]))
    
    ### oov translation {oov word: set({translations})}
    oov_trans = {}

    res = list(tra_tok)
    
    for idx_tra in range(len(tra_tok)):
        ### identify an oov word 
        if idx_tra in oov_pos:
            ### check if the oov word appears 
            ### in the alignment pairs on the translation side
            if idx_tra in tra_lang:
                ### replace the oov word 
                ### with the aligned word from reference
                res[idx_tra] = ref_tok[ref_lang[tra_lang.index(idx_tra)]]
            else:
                idx_ref = 0
                ### iterate through reference tokens,
                ### replace the oov word 
                ### with a word from reference 
                ### that doesn't appear in the translation
                while idx_ref < len(ref_tok) and ref_tok[idx_ref] in res:
                    idx_ref += 1
                
                ### make sure that every oov word is replaced by a word in ref
                if idx_ref != len(ref_tok):
                    res[idx_tra] = ref_tok[idx_ref]
                else:
                    ### randint is inclusive on both sides
                    res[idx_tra] = ref_tok[randint(0,len(ref_tok)-1)]

            ### add the oov:translation to the dictionary
            if tra_tok[idx_tra] not in oov_trans:
                oov_trans[tra_tok[idx_tra]] = {res[idx_tra]}
            else:
                oov_trans[tra_tok[idx_tra]].add(res[idx_tra])

    return res, oov_trans


def align_oov(in_file, out_file):
    '''
    params:
        in_file: path to input to fast-align
        out_file: path to output generated by fast-align
    return:
        None
    '''
    ### parallel text fed to fast-align
    with open(tra_file) as ft, open(ref_file) as fr, open(in_file, 'w') as fp:
        for l_tra in ft:
            l_ref = fr.readline().strip()
            fp.write(l_tra.strip())
            fp.write(" ||| ")
            fp.write(l_ref)
            fp.write('\n')

    ### source: translation with oov
    ### target: reference
    sh(fast_align+" -i "+in_file+" -d -o -v > "+out_file)

    
def oov_trans_bound(method, \
                    metric, \
                    res_file):
    '''
    get the maximum gain on bleu ir meteor
    params:
        method:
            1. align
            2. lattice (sentence level bleu, or meteor)
            3. lattice-align (sentence level bleu, or meteor)
        metric:
            1. bleu
            2. meteor
        res_file: path to oov translation result
    return:
        None
    '''

    ### maximum possible gain based on alignment between reference and translation
    if method == "align":
        ### parallel text fed to fast-align
        triple_pipe = tmp_dir+"triple_pipe"
        ### alignment result produced by fast-align
        forward_align = tmp_dir+"forward_align"
        ### produce alignment
        align_oov(triple_pipe, forward_align)

        ctr = 0
        with open(tra_file) as ft, \
        open(oov_file) as fo, \
        open(ref_file) as fr, \
        open(forward_align) as ff, \
        open(res_file, 'w') as fres, \
        open(oov_aligned_file, 'w') as foa:
            for l_tra in ft:
                l_oov = fo.readline()
                l_ref = fr.readline().strip()
                l_align = ff.readline().strip()
                
                if ctr >= 0:
                    print(ctr)
                    ### html unescaping not happening
                    tra_tok, oov_pos, _ = get_context_oov_pos(l_tra, l_oov)
                    ref_tok = l_ref.split(' ')     
                    pairs = l_align.split(' ')

                    res, oov_trans = translate_oov_by_alignment(tra_tok, oov_pos, ref_tok, pairs)
                    for oov in oov_trans:
                        ### write reference-aligned oov translation to file 
                        ### for other programs to use
                        foa.write('\t'.join([oov]+list(oov_trans[oov]))+'\n')

                    res = ' '.join(res)
                    
                    print(res)
                    fres.write(res+'\n')

                ctr += 1
    
    ### oov-candidate-word-list-based metric bound, with reference words added to the candidate word list
    elif method == "lattice-align":
        ### parallel text fed to fast-align
        triple_pipe = tmp_dir+"triple_pipe_mix"
        ### alignment result produced by fast-align
        forward_align = tmp_dir+"forward_align_mix"
        ### produce alignment
        align_oov(triple_pipe, forward_align)
        
        ctr = 0
        with open(tra_file) as ft, \
        open(oov_file) as fo, \
        open(ref_file) as fr, \
        open(forward_align) as ff, \
        open(res_file, 'w') as fres:
            for l_tra in ft:
                l_oov = fo.readline()
                l_ref = fr.readline().strip()
                l_align = ff.readline().strip()      
                
                if ctr >= 0:
                    
                    ### html unescaping not happening
                    tra_tok, oov_pos, _ = get_context_oov_pos(l_tra, l_oov)
#                     print(tra_tok)
#                     print(oov_pos)
                    ref_tok = l_ref.split(' ')              
                    pairs = l_align.split(' ')
                    
                    ### {oov:{candidate}}
                    _, oov_trans = translate_oov_by_alignment(tra_tok, oov_pos, ref_tok, pairs)
                    
                    ### {oov}
                    oov_words_set = set([tra_tok[i] for i in oov_pos])
                    ### {oov:{candidate:score}}
                    oov_candidates = get_oov_candidates(ug_dict, oov_words_set)
                    
                    ### merge the oracle oov candidates and the actual oov candidates
                    for oov in oov_trans:
                        add_ref_to_oov_candidates(oov_candidates, oov, oov_trans[oov])
                     
                    ### for test set: sentence 316 is super long
                    ### for dev set: sentence 305, 452 is super long
#                     s = [305, 452, 686]
#                     if dataset == "dev":
#                         s = [305, 452]
#                     elif dataset == "test":
#                         s = [316]
                    num_hyp = num_hyp = get_num_hyp(oov_candidates, tra_tok, oov_pos)

                    ### consider all hypotheses at once
#                     if ctr not in s:
                    if num_hyp <= 50**2.8:
                        #print("enumerate all combinations.")
                        ### recursively get all possible combination
                        all_sentences = get_all_sentences(tra_tok, oov_candidates)
                        #print("number of hypotheses: "+str(len(all_sentences)))
                        
#                         hyp_file = tmp_dir+"hyp_mix_"+str(ctr)
#                         ref_file_dup = tmp_dir+"ref_mix_"+str(ctr)
#                         if metric == "bleu":
#                             best_trans = get_best_hyp_bleu(all_sentences, l_ref, hyp_file, ref_file_dup)
#                         elif metric == "meteor":
#                             best_trans = get_best_hyp_meteor(all_sentences, l_ref, hyp_file, ref_file_dup)
                        best_trans = get_best_hyp(all_sentences, l_ref, metric)
                    ### decode the oovs one by one since too many hypotheses to consider all at once
                    else:
                        #print("progress oov by oov")
                        best_trans = get_best_hyp_est(tra_tok, oov_candidates, l_ref, metric)

                    print(ctr)
                    print(best_trans)
                    fres.write(best_trans+'\n')
                
                ctr += 1                   
        
    ### oov candidate word list based
    elif method == "lattice":
        ctr = 0
        with open(tra_file) as ft, \
        open(oov_file) as fo, \
        open(ref_file) as fr, \
        open(res_file, 'w') as fres:
            for l_tra in ft:
                l_oov = fo.readline()
                l_ref = fr.readline().strip()
                
                if ctr >= 0:
                    
                    ### html unescaping not happening
                    tra_tok, oov_pos, _ = get_context_oov_pos(l_tra, l_oov)
                    ### {oov}
                    oov_words_set = set([tra_tok[i] for i in oov_pos])
                    ### {oov:{candidate:score}}
                    oov_candidates = get_oov_candidates(ug_dict, oov_words_set)

                    
                    ### for test set: sentence 316 is super long
                    ### for dev set: sentence 305, 452 is super long
#                     s = [305, 452, 686]
#                     if dataset == "dev":
#                         s = [305, 452]
#                     elif dataset == "test":
#                         s = [316]
                    num_hyp = get_num_hyp(oov_candidates, tra_tok, oov_pos)

#                     if ctr not in s:
                    if num_hyp <= 50**2.8:
                        #print("enumerate all combinations.")
                        ### recursively get all possible combination
                        all_sentences = get_all_sentences(tra_tok, oov_candidates)
#                         hyp_file = tmp_dir+"hyp_"+str(ctr)
#                         ref_file_dup = tmp_dir+"ref_"+str(ctr)
#                         if metric == "bleu":
#                             best_trans = get_best_hyp_bleu(all_sentences, l_ref, hyp_file, ref_file_dup)
#                         elif metric == "meteor":
#                             best_trans = get_best_hyp_meteor(all_sentences, l_ref, hyp_file, ref_file_dup)
                        best_trans = get_best_hyp(all_sentences, l_ref, metric)
                    else:
                        #print("progress oov by oov")
                        #best_trans = ' '.join(tra_tok)                
                        #best_trans = l_ref
                        best_trans = get_best_hyp_est(tra_tok, oov_candidates, l_ref, metric)

                    print(ctr)
                    print(best_trans)
                    fres.write(best_trans+'\n')                

                ctr += 1

# %%
# -------- hyperparameters specific to this method --------
### align or lattice-align or lattice
method = "lattice-align"
### bleu or meteor; make a choice only when method == lattice or lattice-align
metric = "bleu"
    
# -------- write --------
res_file = res_dir+"_".join(["best",metric,method])
if method == "align":
    res_file = res_dir+"_".join(["best","ref",method])

# -------- translate --------
### method:
# 1. lattice
# 2. align
# 3. lattice-align
### metric (applied only when method == lattice, because if method == aligned, then metric isn't used.):
# 1. meteor
# 2. bleu
### result file
    
oov_trans_bound(method, metric, res_file)
# Out:
# number of hypotheses: 1
# 0
# highlight colour ,
# number of hypotheses: 1
# 1
# plan
# number of hypotheses: 1
# 2
# Interactive Console for manipulating currently selected accessible
# number of hypotheses: 1
# 3
# _ C lear L .
# number of hypotheses: 1
# 4
# source
# number of hypotheses: 1
# 5
# Plugin with methods of various selecting accessibles quickly .
# number of hypotheses: 1
# 6
# Dogtail
# number of hypotheses: 1
# 7
# current Script be .
# number of hypotheses: 1
# 8
# _ Schema M ,
# number of hypotheses: 1
# 9
# in vain .
# number of hypotheses: 1
# 10
# role
# number of hypotheses: 1
# 11
# EXCEPT
# number of hypotheses: 1
# 12
# DEBUG
# number of hypotheses: 1
# 13
# basic
# number of hypotheses: 1
# 14
# but than focused WIDGET
# number of hypotheses: 1
# 15
# % s &apos; s brothers , or by label
# number of hypotheses: 1
# 16
# % ( rolename ) s index % ( parent num1 ) d does not match row and column ( num2 index % d
# number of hypotheses: 1
# 17
# _ Contents
# number of hypotheses: 1
# 18
# He . do not turn away .
# number of hypotheses: 1
# 19
# Japanese know .
# number of hypotheses: 1
# 20
# people something .
# number of hypotheses: 1
# 21
# they all a human being ?
# number of hypotheses: 1
# 22
# do speak ?
# number of hypotheses: 1
# 23
# these are nothing but a few ! &quot;
# number of hypotheses: 1
# 24
# He it to be happy .
# number of hypotheses: 1
# 25
# I .
# number of hypotheses: 1
# 26
# &quot; thank you . &quot; &quot; you &apos; re welcome . &quot;
# number of hypotheses: 1
# 27
# I I don &apos; t know him .
# number of hypotheses: 1
# 28
# We we yesterday .
# number of hypotheses: 1
# 29
# don forget .
# number of hypotheses: 1
# 30
# and who will resurrect those who do not know ?
# number of hypotheses: 1
# 31
# Diary a ?
# number of hypotheses: 1
# 32
# Diary a ?
# number of hypotheses: 1
# 33
# whomsoever you ?
# number of hypotheses: 1
# 34
# pardon apologize .
# number of hypotheses: 1
# 35
# pardon apologize .
# number of hypotheses: 1
# 36
# why did you go office ?
# number of hypotheses: 1
# 37
# why did you go office ?
# number of hypotheses: 1
# 38
# you very brave .
# number of hypotheses: 1
# 39
# what you ?
# number of hypotheses: 1
# 40
# what ! ?
# number of hypotheses: 1
# 41
# you clear .
# number of hypotheses: 1
# 42
# there are clear .
# number of hypotheses: 1
# 43
# time from which there ?
# number of hypotheses: 1
# 44
# when will be ?
# number of hypotheses: 1
# 45
# when will this threat come to you ?
# number of hypotheses: 1
# 46
# when will be ?
# number of hypotheses: 1
# 47
# for those who you ?
# number of hypotheses: 1
# 48
# your Follow me makes rejoice .
# number of hypotheses: 1
# 49
# your Follow me makes rejoice .
# number of hypotheses: 1
# 50
# so !
# number of hypotheses: 1
# 51
# and what you do .
# number of hypotheses: 50
# 52
# please , me your me .
# number of hypotheses: 1
# 53
# please , your me .
# number of hypotheses: 1
# 54
# I will for you .
# number of hypotheses: 1
# 55
# you believe .
# number of hypotheses: 1
# 56
# I t .
# number of hypotheses: 1
# 57
# yet you caring .
# number of hypotheses: 1
# 58
# you green green .
# number of hypotheses: 1
# 59
# that you have don much wealth .
# number of hypotheses: 1
# 60
# you , and secure &#93; .
# number of hypotheses: 1
# 61
# the heaven and the blue .
# number of hypotheses: 1
# 62
# an empty room ?
# number of hypotheses: 99
# 63
# a the company million $ may .
# number of hypotheses: 1
# 64
# money comes goes .
# number of hypotheses: 1
# 65
# a Day gold from day .
# number of hypotheses: 1
# 66
# they are angry you ?
# number of hypotheses: 1
# 67
# this eat the ?
# number of hypotheses: 1
# 68
# this eat the ?
# number of hypotheses: 1
# 69
# that is the way of dangerous climb mountain alone .
# number of hypotheses: 1
# 70
# surely I will help you .
# number of hypotheses: 1
# 71
# and they , however much determined from by environment .
# number of hypotheses: 1
# 72
# lo ! must hospitalized in the land .
# number of hypotheses: 1
# 73
# tell them that they do .
# number of hypotheses: 1
# 74
# my uncle , when she came to him who off airport .
# number of hypotheses: 1
# 75
# I usually get up at at six .
# number of hypotheses: 1
# 76
# this is the Book 800 book .
# number of hypotheses: 1
# 77
# I came here . I do not believe .
# number of hypotheses: 1
# 78
# saw him with my own eyes .
# number of hypotheses: 1
# 79
# I don &apos; t TV .
# number of hypotheses: 1
# 80
# I sitting smoking pipe .
# number of hypotheses: 1
# 81
# I I don &apos; t like apples .
# number of hypotheses: 1
# 82
# a looked at the Book .
# number of hypotheses: 2
# 83
# if you attack I English .
# number of hypotheses: 3
# 84
# if you attack I English home .
# number of hypotheses: 1
# 85
# you m .
# number of hypotheses: 1
# 86
# I like , while I love my likes .
# number of hypotheses: 1
# 87
# I m .
# number of hypotheses: 1
# 88
# I I went to church this morning .
# number of hypotheses: 1
# 89
# I destroyed me .
# number of hypotheses: 1
# 90
# I help my yesterday .
# number of hypotheses: 1
# 91
# I don &apos; t have a car , but sister .
# number of hypotheses: 9
# 92
# a week is divided into seven days : I he once week .
# number of hypotheses: 1
# 93
# that for a number of wealth .
# number of hypotheses: 2
# 94
# I was and in .
# number of hypotheses: 1
# 95
# I found a great know .
# number of hypotheses: 1
# 96
# live in Japan .
# number of hypotheses: 1
# 97
# I know them .
# number of hypotheses: 1
# 98
# his busy end of those who do not know .
# number of hypotheses: 1
# 99
# up at eight o &apos; clock .
# number of hypotheses: 1
# 100
# I live know .
# number of hypotheses: 1
# 101
# I like to ) .
# number of hypotheses: 1
# 102
# so that I am I do not believe .
# number of hypotheses: 1
# 103
# We want a car .
# number of hypotheses: 1
# 104
# there are two has hands .
# number of hypotheses: 47
# 105
# next year be born fall Sunday .
# number of hypotheses: 1
# 106
# I with to go .
# number of hypotheses: 51
# 107
# the question to answer .
# number of hypotheses: 1
# 108
# when We bestow favor upon you to help them ?
# number of hypotheses: 1
# 109
# help me .
# number of hypotheses: 1
# 110
# Autumn changed winter .
# number of hypotheses: 1
# 111
# get out !
# number of hypotheses: 1
# 112
# learning calligraphy strange .
# number of hypotheses: 46
# 113
# _ Seicho Matumoto 1992 in die .
# number of hypotheses: 1
# 114
# you &apos; re a reporter .
# number of hypotheses: 1
# 115
# this is kept s years is eight years old .
# number of hypotheses: 1
# 116
# a four chorus &#93; .
# number of hypotheses: 1
# 117
# there .
# number of hypotheses: 1
# 118
# there will be a like red ?
# number of hypotheses: 1
# 119
# five students week week is divided into seven days : that have passed away .
# number of hypotheses: 1
# 120
# for with the teacher .
# number of hypotheses: 1
# 121
# tomorrow . to nonsense .
# number of hypotheses: 1
# 122
# evidently , it &apos; s going to rain they , a painful punishment .
# number of hypotheses: 1
# 123
# who runs &#93; .
# number of hypotheses: 1
# 124
# who knows ?
# number of hypotheses: 1
# 125
# everybody leaving .
# number of hypotheses: 1
# 126
# I ll you .
# number of hypotheses: 2
# 127
# my TV .
# number of hypotheses: 1
# 128
# this is 223-1374 ?
# number of hypotheses: 3
# 129
# you live in ?
# number of hypotheses: 1
# 130
# , please .
# number of hypotheses: 44
# 131
# I ten eighteen years eight .
# number of hypotheses: 1
# 132
# and He has no girlfriend .
# number of hypotheses: 1
# 133
# and your email address hirosey @ genet.co.jp. ,
# number of hypotheses: 1
# 134
# his way thinking might reflect .
# number of hypotheses: 1
# 135
# there away for a number of the Book .
# number of hypotheses: 1
# 136
# and He is Thai well English .
# number of hypotheses: 1
# 137
# the two years land years before .
# number of hypotheses: 1
# 138
# He cannot sing good .
# number of hypotheses: 1
# 139
# is taller than his father .
# number of hypotheses: 1
# 140
# and by that teahouse Tokyo .
# number of hypotheses: 1
# 141
# He knows Mr. recognize the good .
# number of hypotheses: 1
# 142
# and He went away from his father .
# number of hypotheses: 1
# 143
# He how in a leader ?
# number of hypotheses: 1
# 144
# He will , and I am neither do .
# number of hypotheses: 1
# 145
# and to .
# number of hypotheses: 1
# 146
# and by that teahouse fish for eat .
# number of hypotheses: 1
# 147
# He He studied studied the Uyghur language for
# number of hypotheses: 1
# 148
# and He is both music .
# number of hypotheses: 1
# 149
# you may be he rich that worked for him .
# number of hypotheses: 1
# 150
# and now the office building .
# number of hypotheses: 1
# 151
# He sat recites the Book .
# number of hypotheses: 1
# 152
# perhaps he t .
# number of hypotheses: 1
# 153
# they asked them for a question he questioned .
# number of hypotheses: 1
# 154
# He friend brother .
# number of hypotheses: 1
# 155
# and when I find meet with me .
# number of hypotheses: 1
# 156
# He set alarm going before .
# number of hypotheses: 1
# 157
# He is ) .
# number of hypotheses: 1
# 158
# He &apos; s Taro &apos; s younger brother
# number of hypotheses: 1
# 159
# and beset the were witnessing .
# number of hypotheses: 47
# 160
# and how many red sum money to red cross .
# number of hypotheses: 1
# 161
# most surely he is given confused .
# number of hypotheses: 1
# 162
# He it is He himself .
# number of hypotheses: 1
# 163
# there is for his of ideas .
# number of hypotheses: 1
# 164
# when he speech with unique of .
# number of hypotheses: 1
# 165
# and he read write .
# number of hypotheses: 48
# 166
# He tired he spent , even though he to .
# number of hypotheses: 1
# 167
# it will not grieve mother was a school .
# number of hypotheses: 1
# 168
# on the Day of Resurrection , He has knowledge of every day in doubt .
# number of hypotheses: 1
# 169
# and of oxen Tom their names .
# number of hypotheses: 1
# 170
# they it .
# number of hypotheses: 1
# 171
# I sent her a writing love write it down .
# number of hypotheses: 1
# 172
# a her mother was a school .
# number of hypotheses: 1
# 173
# the two passed passed by the day before .
# number of hypotheses: 1
# 174
# to help him .
# number of hypotheses: 1
# 175
# He prize in first .
# number of hypotheses: 1
# 176
# his position the soul very ( others ) .
# number of hypotheses: 1
# 177
# she lives alone in it .
# number of hypotheses: 1
# 178
# He is the doctor ?
# number of hypotheses: 1
# 179
# He brought writing write it down .
# number of hypotheses: 1
# 180
# He who has .
# number of hypotheses: 1
# 181
# does he not fortified her heart watch new .
# number of hypotheses: 1
# 182
# He went with the .
# number of hypotheses: 1
# 183
# the food to cooking .
# number of hypotheses: 40
# 184
# my father has to twice .
# number of hypotheses: 1
# 185
# my father high .
# number of hypotheses: 2
# 186
# my mother hit I live parents , and my mother hit _ with what you reveal .
# number of hypotheses: 1
# 187
# mother was a school teacher .
# number of hypotheses: 1
# 188
# my whatever have your .
# number of hypotheses: 1
# 189
# I dictionary .
# number of hypotheses: 1
# 190
# I .
# number of hypotheses: 1
# 191
# I ) .
# number of hypotheses: 1
# 192
# my has .
# number of hypotheses: 11
# 193
# after you busy tomorrow afternoon ?
# number of hypotheses: 1
# 194
# time to leave tomorrow ?
# number of hypotheses: 1
# 195
# if it should rain , tomorrow I rains .
# number of hypotheses: 48
# 196
# next ten ll be seven years .
# number of hypotheses: 1
# 197
# when the train .
# number of hypotheses: 1
# 198
# then , were a ?
# number of hypotheses: 1
# 199
# my my .
# number of hypotheses: 1
# 200
# come !
# number of hypotheses: 1
# 201
# thank Amazons mercy .
# number of hypotheses: 1
# 202
# We Arabic .
# number of hypotheses: 1
# 203
# He went fell .
# number of hypotheses: 1
# 204
# what ? can hear .
# number of hypotheses: 1
# 205
# this Book to you book ?
# number of hypotheses: 1
# 206
# peace .
# number of hypotheses: 1
# 207
# why not ?
# number of hypotheses: 1
# 208
# I t .
# number of hypotheses: 1
# 209
# I m .
# number of hypotheses: 2
# 210
# thereupon egg into boiling .
# number of hypotheses: 1
# 211
# that ( in ) the wealth .
# number of hypotheses: 1
# 212
# and the adulteress reading .
# number of hypotheses: 1
# 213
# excuse , who is this woman ?
# number of hypotheses: 1
# 214
# made to seem fair to them , Beholder .
# number of hypotheses: 1
# 215
# I m the Number .
# number of hypotheses: 1
# 216
# what is this ?
# number of hypotheses: 1
# 217
# this is my idea .
# number of hypotheses: 1
# 218
# you &apos; re welcome .
# number of hypotheses: 1
# 219
# that that the Book .
# number of hypotheses: 1
# 220
# that this is a Book .
# number of hypotheses: 1
# 221
# He no one in which there is no doubt .
# number of hypotheses: 1
# 222
# those who jest .
# number of hypotheses: 1
# 223
# I came . I have come to you .
# number of hypotheses: 1
# 224
# &#91; not .
# number of hypotheses: 1
# 225
# the men of understanding .
# number of hypotheses: 4
# 226
# you alone ?
# number of hypotheses: 1
# 227
# and falsehood has vanished .
# number of hypotheses: 1
# 228
# what is the food you ?
# number of hypotheses: 1
# 229
# you go !
# number of hypotheses: 1
# 230
# let &apos; s , and to the threat .
# number of hypotheses: 1
# 231
# you wait .
# number of hypotheses: 1
# 232
# you &quot; ? Yes .
# number of hypotheses: 1
# 233
# how s ?
# number of hypotheses: 1
# 234
# He us a good score .
# number of hypotheses: 1
# 235
# they do not good .
# number of hypotheses: 1
# 236
# what He happened away ?
# number of hypotheses: 1
# 237
# 3 cubed are seven .
# number of hypotheses: 1
# 238
# but what is ?
# number of hypotheses: 1
# 239
# Turpan grapes return ( to the famous .
# number of hypotheses: 1
# 240
# Oh ...
# number of hypotheses: 1
# 241
# you at ?
# number of hypotheses: 10
# 242
# don .
# number of hypotheses: 1
# 243
# tomorrow is meeting .
# number of hypotheses: 1
# 244
# don .
# number of hypotheses: 1
# 245
# He works a .
# number of hypotheses: 1
# 246
# what ?
# number of hypotheses: 1
# 247
# the equal is confused .
# number of hypotheses: 1
# 248
# &quot; We to help them . &quot; &quot; ... Hu need my saw .
# number of hypotheses: 1
# 249
# close window going before .
# number of hypotheses: 1
# 250
# it &apos; s just who them .
# number of hypotheses: 1
# 251
# my food cooking .
# number of hypotheses: 50
# 252
# I thinking .
# number of hypotheses: 1
# 253
# the market together !
# number of hypotheses: 3
# 254
# Afrikaners would the originated in Africa .
# number of hypotheses: 6
# 255
# We have chance .
# number of hypotheses: 7
# 256
# chance to do .
# number of hypotheses: 1
# 257
# you speak the truth of the liars .
# number of hypotheses: 1
# 258
# I don &apos; t like the female .
# number of hypotheses: 1
# 259
# do want ? He is very easy ...
# number of hypotheses: 1
# 260
# He shall be seized by done delusion .
# number of hypotheses: 1
# 261
# except for us to be a us looked .
# number of hypotheses: 1
# 262
# or you go , or I go .
# number of hypotheses: 42
# 263
# in case ( I am sick , then I call you , seek to hasten .
# number of hypotheses: 1
# 264
# why do the right path .
# number of hypotheses: 1
# 265
# was a student at that time .
# number of hypotheses: 1
# 266
# their that women much .
# number of hypotheses: 1
# 267
# where you ?
# number of hypotheses: 1
# 268
# this is nothing ?
# number of hypotheses: 1
# 269
# Nay , but the meeting of this may nvidia cliché tomorrow .
# number of hypotheses: 1
# 270
# stay .
# number of hypotheses: 1
# 271
# on the city of peace ! ...
# number of hypotheses: 1
# 272
# Minnesota s state disdaineth not .
# number of hypotheses: 1
# 273
# is food like ?
# number of hypotheses: 1
# 274
# Emet us , it is not with you !
# number of hypotheses: 1
# 275
# a would to .
# number of hypotheses: 45
# 276
# stay kebabs you ?
# number of hypotheses: 1
# 277
# We usually at you forgot the off ?
# number of hypotheses: 45
# 278
# eight enrolled an when to school .
# number of hypotheses: 1
# 279
# said he sang on-stage .
# number of hypotheses: 1
# 280
# perhaps like good crack ?
# number of hypotheses: 1
# 281
# let eat !
# number of hypotheses: 3
# 282
# which of do ?
# number of hypotheses: 1
# 283
# I let the .
# number of hypotheses: 1
# 284
# you an ?
# number of hypotheses: 1
# 285
# what should to ?
# number of hypotheses: 1
# 286
# for you . I have come to you .
# number of hypotheses: 1
# 287
# I was last sick .
# number of hypotheses: 1
# 288
# they are angry , get please Sir ! I have come to a new creation !
# number of hypotheses: 1
# 289
# clock time to go ?
# number of hypotheses: 1
# 290
# this is a clear sentence .
# number of hypotheses: 1
# 291
# the office building workshop .
# number of hypotheses: 1
# 292
# He made wonderful .
# number of hypotheses: 3
# 293
# He good .
# number of hypotheses: 1
# 294
# today s awhile .
# number of hypotheses: 49
# 295
# do ? &quot;
# number of hypotheses: 1
# 296
# He was a love .
# number of hypotheses: 1
# 297
# pay heed !
# number of hypotheses: 1
# 298
# I I don &apos; t know .
# number of hypotheses: 1
# 299
# whereby he have faults ) .
# number of hypotheses: 1
# 300
# do smoke ?
# number of hypotheses: 1
# 301
# I threw .
# number of hypotheses: 1
# 302
# as !
# number of hypotheses: 1
# 303
# Our pilaf four yuan .
# number of hypotheses: 45
# 304
# the rat ! call to be !
# number of hypotheses: 4
# 305
# We the eight yuan pilaf the four . but yuan .
# number of hypotheses: 1
# 306
# you alone today ?
# number of hypotheses: 1
# 307
# it will be all good .
# number of hypotheses: 1
# 308
# who is in the evening up today ?
# number of hypotheses: 2
# 309
# you &apos; re right . that is good bit expensive .
# number of hypotheses: 46
# 310
# beside cut off .
# number of hypotheses: 1
# 311
# We out .
# number of hypotheses: 1
# 312
# will tomorrow ?
# number of hypotheses: 1
# 313
# I ask you taller .
# number of hypotheses: 1
# 314
# don be .
# number of hypotheses: 1
# 315
# He guess dog .
# number of hypotheses: 1
# 316
# what ye ?
# number of hypotheses: 1
# 317
# both speak ?
# number of hypotheses: 1
# 318
# help !
# number of hypotheses: 1
# 319
# you are a way .
# number of hypotheses: 1
# 320
# you are a way .
# number of hypotheses: 1
# 321
# eight child circumcised , when He will .
# number of hypotheses: 1
# 322
# and you come .
# number of hypotheses: 1
# 323
# I love to see .
# number of hypotheses: 1
# 324
# I .
# number of hypotheses: 1
# 325
# I agree .
# number of hypotheses: 1
# 326
# you a !
# number of hypotheses: 1
# 327
# be food .
# number of hypotheses: 1
# 328
# I used to .
# number of hypotheses: 1
# 329
# when . this time ?
# number of hypotheses: 1
# 330
# why re !
# number of hypotheses: 4
# 331
# a twenty are dollars twenty of you turn away .
# number of hypotheses: 221
# 332
# put the Unthurna &quot; .
# number of hypotheses: 1
# 333
# if attack hungry poor .
# number of hypotheses: 1
# 334
# you .
# number of hypotheses: 1
# 335
# this is very beautiful .
# number of hypotheses: 1
# 336
# He is devotion to Him ?
# number of hypotheses: 1
# 337
# desist , I see .
# number of hypotheses: 1
# 338
# He . for him .
# number of hypotheses: 1
# 339
# I started for before this .
# number of hypotheses: 1
# 340
# memorize him light .
# number of hypotheses: 1
# 341
# report , fear not !
# number of hypotheses: 1
# 342
# you back ?
# number of hypotheses: 1
# 343
# the room .
# number of hypotheses: 1
# 344
# I in slain .
# number of hypotheses: 1
# 345
# your here .
# number of hypotheses: 1
# 346
# Brussels the of .
# number of hypotheses: 1
# 347
# did buy pomegranate ?
# number of hypotheses: 1
# 348
# on that day the two of the two females on days .
# number of hypotheses: 1
# 349
# this is got .
# number of hypotheses: 1
# 350
# this is no . there will neither die nor live .
# number of hypotheses: 1
# 351
# this is family me has abode .
# number of hypotheses: 1
# 352
# and I sorry late .
# number of hypotheses: 1
# 353
# follow into me came into the room .
# number of hypotheses: 1
# 354
# I &#91; at the train 7 _ to it , then how _ York 10 at them .
# number of hypotheses: 1
# 355
# I find it hard for Tokyo .
# number of hypotheses: 1
# 356
# him , and I outta .
# number of hypotheses: 2
# 357
# on the Day of Resurrection , every my day a new the Book .
# number of hypotheses: 1
# 358
# after I walk by that teahouse , after Football class .
# number of hypotheses: 1
# 359
# He went with .
# number of hypotheses: 1
# 360
# with before before him in the park .
# number of hypotheses: 1
# 361
# clock will go .
# number of hypotheses: 6
# 362
# from the sky lot in much .
# number of hypotheses: 2
# 363
# I 2003 _ studied 2007 _ from to read .
# number of hypotheses: 1
# 364
# it pointless chase evil .
# number of hypotheses: 1
# 365
# my son is Aksu very !
# number of hypotheses: 1
# 366
# I you do .
# number of hypotheses: 1
# 367
# I you do .
# number of hypotheses: 1
# 368
# got ?
# number of hypotheses: 1
# 369
# problem .
# number of hypotheses: 1
# 370
# I I work in a hospital .
# number of hypotheses: 1
# 371
# work in a hospital .
# number of hypotheses: 1
# 372
# rarely windy ?
# number of hypotheses: 1
# 373
# which come ?
# number of hypotheses: 1
# 374
# there good .
# number of hypotheses: 1
# 375
# a your . did from coal ?
# number of hypotheses: 1
# 376
# you come here every day day ?
# number of hypotheses: 1
# 377
# _ Harvard 1636 1636 a .
# number of hypotheses: 1
# 378
# tomorrow meeting keepers .
# number of hypotheses: 1
# 379
# you have two brothers .
# number of hypotheses: 1
# 380
# a Venice a water will be overturned .
# number of hypotheses: 1
# 381
# this is jasmine tea ?
# number of hypotheses: 1
# 382
# We Football like playing good .
# number of hypotheses: 1
# 383
# sport is good for your health .
# number of hypotheses: 1
# 384
# sport is good for your health .
# number of hypotheses: 1
# 385
# the is near .
# number of hypotheses: 1
# 386
# He said to it by this .
# number of hypotheses: 1
# 387
# they eating a .
# number of hypotheses: 1
# 388
# and a mercy for a few .
# number of hypotheses: 1
# 389
# after what do afternoon ?
# number of hypotheses: 1
# 390
# sleeping a is !
# number of hypotheses: 52
# 391
# if it rains please call me .
# number of hypotheses: 1
# 392
# if it rains , call me .
# number of hypotheses: 1
# 393
# fight war all trading . certainly ,
# number of hypotheses: 1
# 394
# little t Myself .
# number of hypotheses: 1
# 395
# my s .
# number of hypotheses: 1
# 396
# today m go Myself .
# number of hypotheses: 1
# 397
# practically every family of all things .
# number of hypotheses: 1
# 398
# this town city is very .
# number of hypotheses: 1
# 399
# seeing comprise the in much .
# number of hypotheses: 1
# 400
# you t .
# number of hypotheses: 1
# 401
# you didn &apos; t see anything .
# number of hypotheses: 1
# 402
# you t .
# number of hypotheses: 1
# 403
# _ don t ramble .
# number of hypotheses: 1
# 404
# _ don t ramble .
# number of hypotheses: 1
# 405
# this will be brought to whom you have not yet about their punishment .
# number of hypotheses: 1
# 406
# to the novel was written by novel ?
# number of hypotheses: 1
# 407
# clock , it grieves thirty please .
# number of hypotheses: 1
# 408
# at it grieves them , and they please .
# number of hypotheses: 1
# 409
# let &apos; s witnessed .
# number of hypotheses: 1
# 410
# We have made it &quot; call skunk one Man . &quot;
# number of hypotheses: 47
# 411
# in Russia , sentence thee !
# number of hypotheses: 1
# 412
# do they not YouTube network .
# number of hypotheses: 1
# 413
# his lot .
# number of hypotheses: 1
# 414
# respect his selflessness .
# number of hypotheses: 1
# 415
# respect his selflessness .
# number of hypotheses: 1
# 416
# you disappointed me .
# number of hypotheses: 1
# 417
# you that you disappointed me .
# number of hypotheses: 1
# 418
# you that you let me .
# number of hypotheses: 1
# 419
# therefor didn &apos; for to them .
# number of hypotheses: 1
# 420
# We didn &apos; t see him anywhere .
# number of hypotheses: 1
# 421
# I have a test tomorrow .
# number of hypotheses: 1
# 422
# I worked 24 getting .
# number of hypotheses: 1
# 423
# clock He ll when they passed by them .
# number of hypotheses: 1
# 424
# the Sabbath , to do any crack ?
# number of hypotheses: 1
# 425
# the Sabbath , good to look down ?
# number of hypotheses: 1
# 426
# tufts University is a very school famous .
# number of hypotheses: 1
# 427
# they will come to it &apos; s five ?
# number of hypotheses: 1
# 428
# what name ?
# number of hypotheses: 1
# 429
# your &apos; what I ?
# number of hypotheses: 1
# 430
# wisdom does not automatically come with age , in six days .
# number of hypotheses: 1
# 431
# my why did sixty-year-old what a landlord buy trampoline ?
# number of hypotheses: 1
# 432
# this is he who is ?
# number of hypotheses: 1
# 433
# two male work at male and female .
# number of hypotheses: 1
# 434
# my s .
# number of hypotheses: 1
# 435
# We drink our tea with sugar .
# number of hypotheses: 1
# 436
# We drink our tea with sugar .
# number of hypotheses: 1
# 437
# his name name .
# number of hypotheses: 1
# 438
# my the .
# number of hypotheses: 1
# 439
# I &apos; m Suduku Number rise .
# number of hypotheses: 1
# 440
# the who at female .
# number of hypotheses: 1
# 441
# clock &apos; would .
# number of hypotheses: 1
# 442
# who cut build ?
# number of hypotheses: 1
# 443
# He this only around .
# number of hypotheses: 1
# 444
# in a low with voice .
# number of hypotheses: 1
# 445
# in a low with speak .
# number of hypotheses: 1
# 446
# the looks floor a .
# number of hypotheses: 1
# 447
# all other languages easier easy .
# number of hypotheses: 1
# 448
# don come near !
# number of hypotheses: 1
# 449
# this world population _ from year .
# number of hypotheses: 1
# 450
# We called process report .
# number of hypotheses: 1
# 451
# and I am with you . but just witnessed .
# number of hypotheses: 4
# 452
# oranges mean happy love , lemons for the unanswered one .
# number of hypotheses: 1
# 453
# I live know .
# number of hypotheses: 1
# 454
# Polluting &apos; for it .
# number of hypotheses: 1
# 455
# how ? if We .
# number of hypotheses: 1
# 456
# this is a change .
# number of hypotheses: 1
# 457
# He it is for the people of Madinah grave .
# number of hypotheses: 1
# 458
# without make with for ?
# number of hypotheses: 1
# 459
# on the Day of Resurrection , tomorrow Sunday .
# number of hypotheses: 1
# 460
# follow the flowers .
# number of hypotheses: 1
# 461
# she got angry .
# number of hypotheses: 1
# 462
# how the law of for every town .
# number of hypotheses: 1
# 463
# He pays him .
# number of hypotheses: 1
# 464
# it is ton .
# number of hypotheses: 1
# 465
# He went food .
# number of hypotheses: 1
# 466
# We will go into the river tomorrow .
# number of hypotheses: 1
# 467
# this pilaf . this is !
# number of hypotheses: 1
# 468
# let stroll !
# number of hypotheses: 1
# 469
# I have a Book .
# number of hypotheses: 1
# 470
# my mother hit the horse ?
# number of hypotheses: 1
# 471
# how much of it .
# number of hypotheses: 1
# 472
# Oh Is it true ? !
# number of hypotheses: 1
# 473
# who is this this ?
# number of hypotheses: 1
# 474
# I am with you , and are and place .
# number of hypotheses: 1
# 475
# to please score .
# number of hypotheses: 1
# 476
# this is be two after another Rounds will .
# number of hypotheses: 1
# 477
# He is the entire country .
# number of hypotheses: 1
# 478
# He has made witnesses at three . &quot;
# number of hypotheses: 1
# 479
# He ( to be here .
# number of hypotheses: 1
# 480
# they asked about the others .
# number of hypotheses: 1
# 481
# Emet my at bedside at ten .
# number of hypotheses: 1
# 482
# you &apos; men of understanding .
# number of hypotheses: 1
# 483
# I do not accept excuse .
# number of hypotheses: 1
# 484
# I do not accept excuse .
# number of hypotheses: 1
# 485
# you are not a doctor .
# number of hypotheses: 1
# 486
# my father only ten years old .
# number of hypotheses: 1
# 487
# took the bus back .
# number of hypotheses: 1
# 488
# and leave with permission .
# number of hypotheses: 1
# 489
# and leave with permission .
# number of hypotheses: 1
# 490
# sat in the front .
# number of hypotheses: 1
# 491
# the teacher , and I simply didn &apos; t reply Erkin has retired .
# number of hypotheses: 1
# 492
# the Adam with .
# number of hypotheses: 1
# 493
# my Jacques fourteen years old .
# number of hypotheses: 1
# 494
# health of Safety , the matter .
# number of hypotheses: 1
# 495
# looks good score .
# number of hypotheses: 1
# 496
# her fever subsided .
# number of hypotheses: 1
# 497
# the day when the two coughing , after the matter .
# number of hypotheses: 1
# 498
# He is the One home and to stay at home .
# number of hypotheses: 1
# 499
# you re .
# number of hypotheses: 1
# 500
# I &apos; m sorry , to the .
# number of hypotheses: 1
# 501
# amends , have the .
# number of hypotheses: 1
# 502
# you &apos; re a man after all
# number of hypotheses: 1
# 503
# does he still have a temperature ?
# number of hypotheses: 1
# 504
# He does not benefit .
# number of hypotheses: 1
# 505
# He chatted with me
# number of hypotheses: 30
# 506
# when your prescribed .
# number of hypotheses: 30
# 507
# when your eat and drink .
# number of hypotheses: 1
# 508
# let &apos; s female place !
# number of hypotheses: 1
# 509
# and you there is only Emet .
# number of hypotheses: 1
# 510
# it is He who gives me to hall .
# number of hypotheses: 1
# 511
# that museum turned out to be huge
# number of hypotheses: 1
# 512
# this land has all of hues magazines .
# number of hypotheses: 1
# 513
# they gave us a warm greeting .
# number of hypotheses: 1
# 514
# I suddenly needed a car .
# number of hypotheses: 1
# 515
# the sciences harder than social .
# number of hypotheses: 2
# 516
# you have escaped from the at circulation desk .
# number of hypotheses: 1
# 517
# my love , if I finished food .
# number of hypotheses: 1
# 518
# call and the !
# number of hypotheses: 1
# 519
# can , but I will surely can definitely .
# number of hypotheses: 1
# 520
# He &apos; those who give short measure .
# number of hypotheses: 1
# 521
# that , without me , this life had nothing of interest for her to me .
# number of hypotheses: 1
# 522
# hast thou slain a the great contribution .
# number of hypotheses: 1
# 523
# though We bit .
# number of hypotheses: 1
# 524
# I in my womb .
# number of hypotheses: 1
# 525
# I success .
# number of hypotheses: 1
# 526
# a Stephen pretty crazy have .
# number of hypotheses: 1
# 527
# and it took its way to take a son .
# number of hypotheses: 41
# 528
# Wang Ji t , tea beer .
# number of hypotheses: 1
# 529
# she &apos; s my first love .
# number of hypotheses: 1
# 530
# forgive me .
# number of hypotheses: 1
# 531
# see what was your me rejoice .
# number of hypotheses: 1
# 532
# you see what was me rejoice .
# number of hypotheses: 1
# 533
# if questions would be questioned .
# number of hypotheses: 1
# 534
# I am acting help .
# number of hypotheses: 1
# 535
# how do him ?
# number of hypotheses: 52
# 536
# write a me .
# number of hypotheses: 1
# 537
# go with me .
# number of hypotheses: 1
# 538
# I will explain it for you to do .
# number of hypotheses: 1
# 539
# I will explain it for you to do .
# number of hypotheses: 1
# 540
# this is only in with to remorseful .
# number of hypotheses: 1
# 541
# compare him with his older brother ll the .
# number of hypotheses: 1
# 542
# the differences very easily .
# number of hypotheses: 1
# 543
# the differences very easily .
# number of hypotheses: 1
# 544
# the differences very easily .
# number of hypotheses: 1
# 545
# the differences very easily .
# number of hypotheses: 1
# 546
# the difference very easily .
# number of hypotheses: 1
# 547
# the differences very easily .
# number of hypotheses: 1
# 548
# Bob ate snail , then .
# number of hypotheses: 1
# 549
# I won I don &apos; t smoke .
# number of hypotheses: 1
# 550
# went outside and saw Adil .
# number of hypotheses: 1
# 551
# the bus took off . and took ,
# number of hypotheses: 1
# 552
# the bus took off . and took ,
# number of hypotheses: 1
# 553
# the bus the off , he took off .
# number of hypotheses: 1
# 554
# you , and I was happy .
# number of hypotheses: 1
# 555
# don &apos; t trust businessmen .
# number of hypotheses: 1
# 556
# but are 80 Uyghur .
# number of hypotheses: 1
# 557
# no three one on the Day of Resurrection , that there may be born .
# number of hypotheses: 1
# 558
# We many of .
# number of hypotheses: 1
# 559
# today I m to school .
# number of hypotheses: 1
# 560
# measure seven times , cut once .
# number of hypotheses: 1
# 561
# go to the bazaar every Sunday afternoon
# number of hypotheses: 1
# 562
# I go to the bazaar every Sunday afternoon
# number of hypotheses: 1
# 563
# Our boss in the meeting of this .
# number of hypotheses: 4
# 564
# the day when the two armies had fight to fight you , that they should fight oppose one another those and fight them , and the Hour is who should should can likes .
# number of hypotheses: 1
# 565
# we them them .
# number of hypotheses: 1
# 566
# five but He ) , thus permitting I before .
# number of hypotheses: 1
# 567
# He &apos; re going to Kashgar .
# number of hypotheses: 1
# 568
# no t you today .
# number of hypotheses: 1
# 569
# no like you today .
# number of hypotheses: 1
# 570
# no t you today .
# number of hypotheses: 1
# 571
# no like you today .
# number of hypotheses: 1
# 572
# no work completed grieves for a while .
# number of hypotheses: 1
# 573
# wipe tears .
# number of hypotheses: 1
# 574
# thou art of the Sabbath they Saturdays well .
# number of hypotheses: 1
# 575
# you were of the Sabbath Saturdays well .
# number of hypotheses: 1
# 576
# you were of the Sabbath on well .
# number of hypotheses: 1
# 577
# you hear meeting today .
# number of hypotheses: 1
# 578
# you hear meeting today .
# number of hypotheses: 1
# 579
# you hear meeting today .
# number of hypotheses: 1
# 580
# you hear meeting today .
# number of hypotheses: 1
# 581
# I came into the room to find her watching TV .
# number of hypotheses: 1
# 582
# I saw that you have not yet to .
# number of hypotheses: 1
# 583
# their London the abode of the Hereafter .
# number of hypotheses: 1
# 584
# He has dearly me .
# number of hypotheses: 1
# 585
# all of them are from Iceland .
# number of hypotheses: 1
# 586
# are ?
# number of hypotheses: 1
# 587
# a there spirit sick .
# number of hypotheses: 44
# 588
# you really expressed quite clearly .
# number of hypotheses: 1
# 589
# I &apos; ve been studying the _ on them .
# number of hypotheses: 1
# 590
# Daniel , give the policemen .
# number of hypotheses: 1
# 591
# the similitude of the sentence way .
# number of hypotheses: 1
# 592
# He make the Book .
# number of hypotheses: 1
# 593
# thou art the best of the Book He book .
# number of hypotheses: 1
# 594
# you find them the Book and the best .
# number of hypotheses: 1
# 595
# if would be questioned .
# number of hypotheses: 1
# 596
# it is plane at .
# number of hypotheses: 1
# 597
# so both defeat sent a everyday for it .
# number of hypotheses: 1
# 598
# He s of .
# number of hypotheses: 1
# 599
# today got a lot of things done today
# number of hypotheses: 1
# 600
# my it the first of the fire .
# number of hypotheses: 1
# 601
# I I was very satisfied with this .
# number of hypotheses: 1
# 602
# my conditions &apos; good .
# number of hypotheses: 1
# 603
# since he didn &apos; t come , I didn &apos; t go either .
# number of hypotheses: 1
# 604
# from the sky , go to didn &apos; t go either .
# number of hypotheses: 53
# 605
# give me a cigarette .
# number of hypotheses: 1
# 606
# and of every thing single .
# number of hypotheses: 1
# 607
# from a single towel me to be .
# number of hypotheses: 1
# 608
# bring me a single towel .
# number of hypotheses: 1
# 609
# I would late .
# number of hypotheses: 1
# 610
# a baby camel is younger than a
# number of hypotheses: 1
# 611
# very re too .
# number of hypotheses: 1
# 612
# very re too .
# number of hypotheses: 1
# 613
# I gave tambourine a .
# number of hypotheses: 1
# 614
# call the doctor !
# number of hypotheses: 1
# 615
# you are re .
# number of hypotheses: 1
# 616
# soon be .
# number of hypotheses: 1
# 617
# a with a Uyghur met Belarusian , so they will with the language of each ?
# number of hypotheses: 1
# 618
# when you time ?
# number of hypotheses: 1
# 619
# let s !
# number of hypotheses: 1
# 620
# your are getting more .
# number of hypotheses: 4
# 621
# as a code of Uyghur verbs there are are that - primary and helper .
# number of hypotheses: 1
# 622
# this is against law .
# number of hypotheses: 1
# 623
# you are qualified to be the doctor .
# number of hypotheses: 1
# 624
# Daniel , give a Uyghur .
# number of hypotheses: 1
# 625
# you would not have entered take .
# number of hypotheses: 1
# 626
# I ve of .
# number of hypotheses: 1
# 627
# that you your car ?
# number of hypotheses: 1
# 628
# &quot; what is your name &apos; s your name ? &quot; .
# number of hypotheses: 1
# 629
# &quot; I what &apos; s your name ? &quot; .
# number of hypotheses: 1
# 630
# a lion cattle .
# number of hypotheses: 1
# 631
# this is many in to fall into hardship .
# number of hypotheses: 1
# 632
# let return .
# number of hypotheses: 1
# 633
# they are a thousand thousand .
# number of hypotheses: 1
# 634
# He will be informed of asleep .
# number of hypotheses: 1
# 635
# thank mercy .
# number of hypotheses: 2
# 636
# I with my .
# number of hypotheses: 1
# 637
# and a say .
# number of hypotheses: 1
# 638
# why should you TV about a new creation ?
# number of hypotheses: 1
# 639
# this you flower good ?
# number of hypotheses: 1
# 640
# Samantha .
# number of hypotheses: 1
# 641
# do not of .
# number of hypotheses: 1
# 642
# it is Our are hardships .
# number of hypotheses: 1
# 643
# there away .
# number of hypotheses: 1
# 644
# Yes , so far as I know that .
# number of hypotheses: 1
# 645
# a statement of what he says ) ?
# number of hypotheses: 1
# 646
# my French is crappy .
# number of hypotheses: 1
# 647
# as sat played , dutar thought you .
# number of hypotheses: 1
# 648
# you get ?
# number of hypotheses: 1
# 649
# you get ?
# number of hypotheses: 1
# 650
# the exhausted .
# number of hypotheses: 1
# 651
# it likes to smoke tobacco .
# number of hypotheses: 1
# 652
# like Ozodbek I love .
# number of hypotheses: 1
# 653
# He &apos; s in the well .
# number of hypotheses: 1
# 654
# He &apos; s in the well .
# number of hypotheses: 1
# 655
# the people cynical with .
# number of hypotheses: 1
# 656
# open Sesame Sesame !
# number of hypotheses: 1
# 657
# throw food at those who throw stones .
# number of hypotheses: 1
# 658
# thus he be ! much .
# number of hypotheses: 1
# 659
# except to come ?
# number of hypotheses: 1
# 660
# He has given me , I because killed it .
# number of hypotheses: 1
# 661
# a two try kill I birds , with a go to America present during business log &apos; States .
# number of hypotheses: 1
# 662
# she him , they should spend .
# number of hypotheses: 1
# 663
# those to whom t honour to do .
# number of hypotheses: 1
# 664
# such is the truth , from plane .
# number of hypotheses: 1
# 665
# a group of relationships playing downstairs .
# number of hypotheses: 1
# 666
# for come out one .
# number of hypotheses: 1
# 667
# this is the may ,
# number of hypotheses: 1
# 668
# H help F1 ?
# number of hypotheses: 10
# 669
# and those who image photos DICOM Medical network program
# number of hypotheses: 1
# 670
# Bomber
# number of hypotheses: 1
# 671
# sick records Manager
# number of hypotheses: 1
# 672
# in the end was taken away kidnapped could Embark on process and marked , from the land sinister Lederhosen suspiciously and overlook .
# number of hypotheses: 1
# 673
# &apos; s Help Hannah Horse
# number of hypotheses: 11
# 674
# read ( with chat other IRC Internet Relay Chat ) through Allah using program
# number of hypotheses: 1
# 675
# for them opponents make explode
# number of hypotheses: 1
# 676
# NZB the help download from Usenet
# number of hypotheses: 1
# 677
# help frog cross help
# number of hypotheses: 1
# 678
# quake : Scourge of Armagon
# number of hypotheses: 1
# 679
# and who , being abased ,
# number of hypotheses: 1
# 680
# when a translation files Translation . do not be program
# number of hypotheses: 1
# 681
# Virus
# number of hypotheses: 1
# 682
# IRC by Allah using program
# number of hypotheses: 1
# 683
# ( compiled Compiled ) HTML CHM ( ) help file viewer
# number of hypotheses: 1
# 684
# you had known the problem information the developers help shall be gathered .
# number of hypotheses: 4
# 685
# path file desktops Information with to make a mockery of . in this for a term appointed crash specifying database authentication ID debug Information for support . user -g , --default -o -s , or in the least , except by the remembrance .

# %%
print(dataset)
# Out:
# dev

# %%
print(s)
# Out:
# il3
